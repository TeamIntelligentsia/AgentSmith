# %%
###Data Exploration-Hemank###

# %%
import numpy as np

# %%
import pandas as pd

# %%
df=pd.read_csv('/Users/hlamba/Documents/DSSG/Project_Week1/AgentSmith/Data/Building_Violations_sample_50000.csv')
# Out:
# /Users/hlamba/anaconda/lib/python2.7/site-packages/pandas/io/parsers.py:1159: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)

# %%
df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-72b44c061663> in <module>()
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
df.head()
df.tail(3)
# Out:
#        Unnamed: 0       ID VIOLATION LAST MODIFIED DATE VIOLATION DATE  \
# 49997       49997  1430847                   10/14/2008     01/01/2006
# 49998       49998  1734149                   09/16/2008     01/01/2006
# 49999       49999  1834762                   01/12/2007     01/01/2006
#
#       VIOLATION CODE VIOLATION STATUS VIOLATION STATUS DATE  \
# 49997       CN031013         COMPLIED            07/10/2008
# 49998       CN135016         COMPLIED            09/05/2008
# 49999       CN190019         COMPLIED            01/11/2007
#
#             VIOLATION DESCRIPTION VIOLATION LOCATION  \
# 49997  FIRE EXTNGSHR REQ, RESDNTL                NaN
# 49998                MICE/RODENTS                NaN
# 49999  ARRANGE PREMISE INSPECTION                NaN
#
#                             VIOLATION INSPECTOR COMMENTS  \
# 49997            ALL ELEVATION MISSING FIRE EXTINGUISHER
# 49998                                   MICE ON PREMISES
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0              ID  INSPECTION NUMBER  PROPERTY GROUP  \
# count  50000.000000    50000.000000       50000.000000    50000.000000
# mean   24999.500000  3300031.329640     6195288.986320   197729.741420
# std    14433.901067  1088123.083684     4296079.998463   183132.260836
# min        0.000000   742158.000000      375113.000000     1001.000000
# 25%    12499.750000  2400057.500000     2021217.500000    20600.750000
# 50%    24999.500000  3421152.000000     2813561.000000   142605.000000
# 75%    37499.250000  4223617.750000    10630848.750000   363929.250000
# max    49999.000000  5064815.000000    11597625.000000   663759.000000
#
#            LATITUDE     LONGITUDE
# count  49952.000000  49952.000000
# mean      41.845539    -87.673442
# std        0.087437      0.057008
# min       41.644712    -87.914436
# 25%       41.771440    -87.714271
# 50%       41.854001    -87.670709
# 75%       41.912843    -87.634551
# max       42.022645    -87.525898

# %%
del df['Unnamed: 0']
import re
def spaces_to_snake(column_name):
    s = re.sub(r"\s+", '_', column_name)
    return s.lower()

df.columns = [spaces_to_snake(col) for col in df.columns]

# %%
pd.unique(df.latitude)
# Out:
# array([ 41.7330894 ,  41.77708793,  41.93799454, ...,  41.78226348,
#         41.80287663,  41.9977008 ])

# %%
pd.unique(df.longitude)
# Out:
# array([-87.60618433, -87.61569443, -87.70865671, ..., -87.61044672,
#        -87.60990755, -87.68514656])

# %%
len(pd.value_counts(df.latitude))
# Out:
# 34647

# %%
df.latitude.nunique
# Out:
# <bound method Series.nunique of 0     41.733089
# 1     41.777088
# 2     41.937995
# 3     41.937995
# 4     41.791470
# 5     41.812187
# 6     41.791470
# 7     41.765487
# 8     41.963291
# 9     41.988844
# 10    41.956154
# 11    41.956154
# 12    41.799958
# 13    41.838454
# 14    41.794758
# ...
# 49985    41.998311
# 49986    41.967962
# 49987    41.943685
# 49988    41.908694
# 49989    41.856963
# 49990    41.782263
# 49991    41.802877
# 49992    41.778666
# 49993    41.802877
# 49994    41.997701
# 49995    41.751683
# 49996    41.881299
# 49997    41.776074
# 49998    41.806381
# 49999    41.883310
# Name: latitude, Length: 50000, dtype: float64>

# %%
df[df.department_bureau=="CONSERVATION"]
# Out:
#             id violation_last_modified_date violation_date violation_code  \
# 0      5063843                   05/21/2015     05/21/2015       CN065014
# 1      5063990                   05/21/2015     05/21/2015       CN044013
# 2      5064022                   05/21/2015     05/21/2015       CN104035
# 3      5064019                   05/21/2015     05/21/2015       CN196029
# 4      5064139                   05/21/2015     05/21/2015       CN104015
# 5      5064153                   05/21/2015     05/21/2015       CN190019
# 6      5064141                   05/21/2015     05/21/2015       CN015062
# 7      5064257                   05/21/2015     05/21/2015       CN065034
# 8      5064728                   05/21/2015     05/21/2015       CN196029
# 9      5064742                   05/21/2015     05/21/2015       CN190019
# 10     5064812                   05/21/2015     05/21/2015       CN104065
# 11     5064815                   05/21/2015     05/21/2015       CN063014
# ...

# %%
df[(df.latitude>41.78888888) & (df.department_bureau=="CONSERVATION")]
# Out:
#             id violation_last_modified_date violation_date violation_code  \
# 2      5064022                   05/21/2015     05/21/2015       CN104035
# 3      5064019                   05/21/2015     05/21/2015       CN196029
# 4      5064139                   05/21/2015     05/21/2015       CN104015
# 5      5064153                   05/21/2015     05/21/2015       CN190019
# 6      5064141                   05/21/2015     05/21/2015       CN015062
# 8      5064728                   05/21/2015     05/21/2015       CN196029
# 9      5064742                   05/21/2015     05/21/2015       CN190019
# 10     5064812                   05/21/2015     05/21/2015       CN104065
# 11     5064815                   05/21/2015     05/21/2015       CN063014
# 12     5063772                   05/20/2015     05/20/2015       CN070024
# 14     5063763                   05/20/2015     05/20/2015       CN041063
# 19     5064353                   05/20/2015     05/20/2015       CN070014
# ...
