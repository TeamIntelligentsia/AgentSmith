# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/Users/eugeniagiraudy/DSSG/AgentSmith/Data/Building_Violations_sample_50000.csv')

# %%
df.head(10)
# Out:
#    Unnamed: 0       ID VIOLATION LAST MODIFIED DATE VIOLATION DATE  \
# 0           0  5063843                   05/21/2015     05/21/2015
# 1           1  5063990                   05/21/2015     05/21/2015
# 2           2  5064022                   05/21/2015     05/21/2015
# 3           3  5064019                   05/21/2015     05/21/2015
# 4           4  5064139                   05/21/2015     05/21/2015
# 5           5  5064153                   05/21/2015     05/21/2015
# 6           6  5064141                   05/21/2015     05/21/2015
# 7           7  5064257                   05/21/2015     05/21/2015
# 8           8  5064728                   05/21/2015     05/21/2015
# 9           9  5064742                   05/21/2015     05/21/2015
#
#   VIOLATION CODE VIOLATION STATUS VIOLATION STATUS DATE  \
# 0       CN065014             OPEN                   NaN
# 1       CN044013             OPEN                   NaN
# 2       CN104035             OPEN                   NaN
# ...

# %%
df.shape
# Out:
# (50000, 23)

# %%
df.dtypes
# Out:
# Unnamed: 0                        int64
# ID                                int64
# VIOLATION LAST MODIFIED DATE     object
# VIOLATION DATE                   object
# VIOLATION CODE                   object
# VIOLATION STATUS                 object
# VIOLATION STATUS DATE            object
# VIOLATION DESCRIPTION            object
# VIOLATION LOCATION               object
# VIOLATION INSPECTOR COMMENTS     object
# VIOLATION ORDINANCE              object
# INSPECTOR ID                     object
# INSPECTION NUMBER                 int64
# INSPECTION STATUS                object
# INSPECTION WAIVED                object
# INSPECTION CATEGORY              object
# DEPARTMENT BUREAU                object
# ADDRESS                          object
# PROPERTY GROUP                    int64
# SSA                              object
# LATITUDE                        float64
# LONGITUDE                       float64
# LOCATION                         object
# dtype: object

# %%
del df['Unnamed: 0']

# %%
df.columns
# Out:
# Index([u'ID', u'VIOLATION LAST MODIFIED DATE', u'VIOLATION DATE', u'VIOLATION CODE', u'VIOLATION STATUS', u'VIOLATION STATUS DATE', u'VIOLATION DESCRIPTION', u'VIOLATION LOCATION', u'VIOLATION INSPECTOR COMMENTS', u'VIOLATION ORDINANCE', u'INSPECTOR ID', u'INSPECTION NUMBER', u'INSPECTION STATUS', u'INSPECTION WAIVED', u'INSPECTION CATEGORY', u'DEPARTMENT BUREAU', u'ADDRESS', u'PROPERTY GROUP', u'SSA', u'LATITUDE', u'LONGITUDE', u'LOCATION'], dtype='object')

# %%
import re

def spaces_to_snake(column_name):
    """
    converts a string that has spaces into snake_case
    Example:
        print camel_to_snake("KENNY BROUGHT HIS WIFE")
        > KENNY_BROUGHT_HIS_WIFE
    To see how to apply this to camel case, see:
        http://stackoverflow.com/questions/1175208/elegant-python-function-to-convert-camelcase-to-camel-case
    """
    s = re.sub(r"\s+", '_', column_name)
    return s.lower()

df.columns = [spaces_to_snake(col) for col in df.columns]

# %%
df.violation_date.head()
# Out:
# 0    05/21/2015
# 1    05/21/2015
# 2    05/21/2015
# 3    05/21/2015
# 4    05/21/2015
# Name: violation_date, dtype: object

# %%
df.violation_date = pd.to_datetime(df.violation_date)
df.violation_date.head()
# Out:
# 0   2015-05-21
# 1   2015-05-21
# 2   2015-05-21
# 3   2015-05-21
# 4   2015-05-21
# Name: violation_date, dtype: datetime64[ns]

# %%
df.describe
# Out:
# <bound method DataFrame.describe of             id violation_last_modified_date violation_date violation_code  \
# 0      5063843                   05/21/2015     2015-05-21       CN065014
# 1      5063990                   05/21/2015     2015-05-21       CN044013
# 2      5064022                   05/21/2015     2015-05-21       CN104035
# 3      5064019                   05/21/2015     2015-05-21       CN196029
# 4      5064139                   05/21/2015     2015-05-21       CN104015
# 5      5064153                   05/21/2015     2015-05-21       CN190019
# 6      5064141                   05/21/2015     2015-05-21       CN015062
# 7      5064257                   05/21/2015     2015-05-21       CN065034
# 8      5064728                   05/21/2015     2015-05-21       CN196029
# 9      5064742                   05/21/2015     2015-05-21       CN190019
# 10     5064812                   05/21/2015     2015-05-21       CN104065
# ...

# %%
df.describe()
# Out:
#                    id  inspection_number  property_group      latitude  \
# count    50000.000000       50000.000000    50000.000000  49952.000000
# mean   3300031.329640     6195288.986320   197729.741420     41.845539
# std    1088123.083684     4296079.998463   183132.260836      0.087437
# min     742158.000000      375113.000000     1001.000000     41.644712
# 25%    2400057.500000     2021217.500000    20600.750000     41.771440
# 50%    3421152.000000     2813561.000000   142605.000000     41.854001
# 75%    4223617.750000    10630848.750000   363929.250000     41.912843
# max    5064815.000000    11597625.000000   663759.000000     42.022645
#
#           longitude
# count  49952.000000
# mean     -87.673442
# std        0.057008
# min      -87.914436
# 25%      -87.714271
# 50%      -87.670709
# 75%      -87.634551
# max      -87.525898

# %%
pd.value_counts(df.inspection_status)
# Out:
# FAILED    38371
# PASSED     6426
# CLOSED     5199
# HOLD          4
# dtype: int64

# %%
pd.value_counts(df.violation_inspector_comments.isnull())
# Out:
# False    44705
# True      5295
# dtype: int64

# %%
df.violation_inspector_comments = df.violation_inspector_comments.fillna('No Comment')df.g

# %%
pd.value_counts(df.violation_inspector_comments.isnull())
# Out:
# False    50000
# dtype: int64

# %%
df[df.violation_inspector_comments=='No Comment'].head()
# Out:
#          id violation_last_modified_date violation_date violation_code  \
# 13  5063459                   05/20/2015     2015-05-20       CN193019
# 15  5063885                   05/21/2015     2015-05-20         BR1001
# 16  5063912                   05/21/2015     2015-05-20       PL151137
# 18  5063320                   05/20/2015     2015-05-20       CN193019
# 20  5064410                   05/20/2015     2015-05-20       CN193039
#
#    violation_status violation_status_date           violation_description  \
# 13             OPEN                   NaN  REPAIR/WRECK DANGER RESID PREM
# 15             OPEN                   NaN    OWNER OR LICENSED CONTRACTOR
# 16             OPEN                   NaN                            OPEN
# 18             OPEN                   NaN  REPAIR/WRECK DANGER RESID PREM
# 20             OPEN                   NaN   POST OWNER NAME OF VACNT BLDG
#
#    violation_location violation_inspector_comments  \
# ...

# %%
df.violation_status[3:10]
# Out:
# 3    OPEN
# 4    OPEN
# 5    OPEN
# 6    OPEN
# 7    OPEN
# 8    OPEN
# 9    OPEN
# Name: violation_status, dtype: object

# %%
df.iloc[3:10,1:4]
# Out:
#   violation_last_modified_date violation_date violation_code
# 3                   05/21/2015     2015-05-21       CN196029
# 4                   05/21/2015     2015-05-21       CN104015
# 5                   05/21/2015     2015-05-21       CN190019
# 6                   05/21/2015     2015-05-21       CN015062
# 7                   05/21/2015     2015-05-21       CN065034
# 8                   05/21/2015     2015-05-21       CN196029
# 9                   05/21/2015     2015-05-21       CN190019

# %%
df['log_lat'] = df.latitude.apply(np.log)
df[['latitude','log_lat']].head()
# Out:
#     latitude   log_lat
# 0  41.733089  3.731294
# 1  41.777088  3.732348
# 2  41.937995  3.736192
# 3  41.937995  3.736192
# 4  41.791470  3.732692

# %%
df['new_lat'] = df.latitude.apply(lambda x: x + np.random.rand())

# %%
df[['latitude','new_lat','log_lat']].head()
# Out:
#     latitude    new_lat   log_lat
# 0  41.733089  42.461273  3.731294
# 1  41.777088  42.412649  3.732348
# 2  41.937995  42.795645  3.736192
# 3  41.937995  42.108990  3.736192
# 4  41.791470  42.769118  3.732692

# %%
df.columns
# Out:
# Index([u'id', u'violation_last_modified_date', u'violation_date', u'violation_code', u'violation_status', u'violation_status_date', u'violation_description', u'violation_location', u'violation_inspector_comments', u'violation_ordinance', u'inspector_id', u'inspection_number', u'inspection_status', u'inspection_waived', u'inspection_category', u'department_bureau', u'address', u'property_group', u'ssa', u'latitude', u'longitude', u'location', u'log_lat', u'new_lat'], dtype='object')

# %%
df.groupby('department_bureau')

# %%
df.groupby("department_bureau").mean()
# Out:
#                                  id  inspection_number  property_group  \
# department_bureau
# BOILER                      3187754            6534207          250911
# CONSERVATION                3182004            5599306          182792
# CONSTRUCTION EQUIPMENT      3843828            9226801          296070
# DEMOLITION                  4230535           10161867          303974
# ELECTRICAL                  3148057            6082962          226475
# ELEVATOR                    4030558            8923590           99430
# IRON                        3440557            8065067           87547
# NEW CONSTRUCTION            2984252            5171424          229395
# PLUMBING                    3162547            5747402          249322
# REFRIGERATION               3187633            5082480          200453
# SIGNS                       3270825            5902844          211517
# SPECIAL INSPECTION PROGRAM  3456048            7541672          185044
# ...

# %%
df.describe()
# Out:
#                    id  inspection_number  property_group      latitude  \
# count    50000.000000       50000.000000    50000.000000  49952.000000
# mean   3300031.329640     6195288.986320   197729.741420     41.845539
# std    1088123.083684     4296079.998463   183132.260836      0.087437
# min     742158.000000      375113.000000     1001.000000     41.644712
# 25%    2400057.500000     2021217.500000    20600.750000     41.771440
# 50%    3421152.000000     2813561.000000   142605.000000     41.854001
# 75%    4223617.750000    10630848.750000   363929.250000     41.912843
# max    5064815.000000    11597625.000000   663759.000000     42.022645
#
#           longitude       log_lat       new_lat
# count  49952.000000  49952.000000  49952.000000
# mean     -87.673442      3.733983     42.345777
# std        0.057008      0.002090      0.301529
# min      -87.914436      3.729174     41.655426
# 25%      -87.714271      3.732213     42.095397
# ...

# %%
pd.value_counts(df.latitude)
# Out:
# 41.914820    27
# 42.008536    16
# 41.886707    15
# 41.765055    13
# 41.689810    13
# 41.777185    13
# 42.005303    12
# 41.750455    12
# 41.753964    12
# 42.005620    11
# 41.690656    10
# 42.021259    10
# 41.751374    10
# 41.877528    10
# 41.882686    10
# ...
# 41.962547    1
# 41.701752    1
# 41.975556    1
# 41.984772    1
# 41.998689    1
# 41.928147    1
# 41.965897    1
# 41.767182    1
# 41.703995    1
# 41.763078    1
# 41.736848    1
# 41.764741    1
# 41.807683    1
# 41.871751    1
# 41.765245    1
# Length: 34647, dtype: int64

# %%
pd.value_counts(df.department_bureau)
# Out:
# CONSERVATION                  32656
# SPECIAL TASK FORCE             4491
# DEMOLITION                     3185
# ELEVATOR                       1624
# ELECTRICAL                     1551
# PLUMBING                       1412
# NEW CONSTRUCTION               1375
# REFRIGERATION                   932
# BOILER                          740
# VENTILATION                     713
# IRON                            493
# SPECIAL INSPECTION PROGRAM      453
# SIGNS                           339
# WATER                            30
# CONSTRUCTION EQUIPMENT            6
# dtype: int64

# %%
pd.unique(df.department_bureau)
# Out:
# array(['CONSERVATION', 'DEMOLITION', 'BOILER', 'PLUMBING', 'VENTILATION',
#        'ELECTRICAL', 'ELEVATOR', 'SPECIAL TASK FORCE', 'WATER',
#        'SPECIAL INSPECTION PROGRAM', 'REFRIGERATION', 'SIGNS', 'IRON',
#        'NEW CONSTRUCTION', 'CONSTRUCTION EQUIPMENT'], dtype=object)

# %%
pd.unique(df.latitude)
# Out:
# array([ 41.7330894 ,  41.77708793,  41.93799454, ...,  41.78226348,
#         41.80287663,  41.9977008 ])

# %%
pd.unique(df.violation_location)
# Out:
# array(['OTHER   :    :', 'OTHER   :    :MULTIPLE FLOORS', 'EXTERIOR:W   :',
#        ..., 'B. ADEBAYO COMPLIED', 'RICK NOWAK COMPLIED BL00943',
#        'OTHER   :    : (REWRITE) BL01041'], dtype=object)

# %%
pd.unique(df.violation_description)
# Out:
# array(['REPAIR LINTELS', 'PIPE OPENING W/NONCOMBUST MATL',
#        'MAINTAIN WINDOW', 'POST OWNER/MANAGERS NAME/#',
#        'REPLCE WINDOW PANES, PLEXGLAS', 'ARRANGE PREMISE INSPECTION',
#        'OBSTRUCTIONS IN EXIT WAY', 'REPAIR WINDOW SILLS',
#        'REPAIR WINDOW HARDWARE', 'CHIMNEY', 'REPAIR PORCH SYSTEM',
#        'REPAIR/WRECK DANGER RESID PREM', 'CUT OR REMOVE HIGH WEEDS',
#        'OWNER OR LICENSED CONTRACTOR', 'OPEN',
#        'SERVICE WALK, PASSAGE, AREAWAY', 'REPAIR EXTERIOR STAIR',
#        'POST OWNER NAME OF VACNT BLDG', 'INTERNAL', 'EGRESS -BASEMENT',
#        'EGRESS', 'REPAIR EXTERIOR WALL', 'PROVIDE DEADLOCK FOR ENTRANCE',
#        'PROVIDE GUTTER & DOWNSPOUT', 'WATCHMAN', 'REPAIR COPING',
#        'FILE BLDG REGISTRATION', 'UNAPPROVED HEATING DEVICE',
#        'ARRANGE COMPLETED PERMIT INSP.', 'MAINTAN BLDG IN SAFE CONDITION',
#        'DWELLING CLEAN AND SANITARY', 'PROVIDE GUARD RAIL 42 IN HIGH',
# ...

# %%
pd.value_counts(pd.unique(df.violation_description))
# Out:
# HOOD 14 BLACKIRON 18 STAINLESS    1
# PROVIDE LAV TO FAMILY UNIT        1
# MAINT VERT RECIP CONVEYOR         1
# SUBMIT REVISED PLANS FOR PERMT    1
# MECH EXHST/REMOVE CONTAMT'S.      1
# NO PERMIT FLAT SIGN               1
# HEATING PLANT SEPARATION          1
# ILLUMINATE ROOMS AND HALLS        1
# REP/REPL ELECWIRING FORLITEING    1
# F.E. RAILS                        1
# ROOF DRAINAGE FLOOD ADJCNT LOT    1
# REPAIR SCREENS                    1
# PROV PRES/TEMP RLF VAL FOR HWH    1
# STRAP SERVICE CONDUIT             1
# GROUND DOORBELL TRANS             1
# ...
# REPAIR EXTERIOR DOOR FRAME        1
# FIRE EXTNGSHR REQ, NONRESDNTL     1
# III-B AND IV-A FIRE RESISTANCE    1
# FIRE EXTNGSHR REQ, RESDNTL        1
# MAINTAIN WINDOW                   1
# SEAL CRACKED BRICKWORK            1
# REPL DEF HOIST ROPES FRT          1
# LICENSED CONTRACTOR               1
# SUBMIT PLANS FOR PLUMBING PRMT    1
# OCCUPIED WITHOUT REQ'D C OF O     1
# REPAIR ROOF STRUCTURE             1
# ...

# %%
df.columns
# Out:
# Index([u'id', u'violation_last_modified_date', u'violation_date', u'violation_code', u'violation_status', u'violation_status_date', u'violation_description', u'violation_location', u'violation_inspector_comments', u'violation_ordinance', u'inspector_id', u'inspection_number', u'inspection_status', u'inspection_waived', u'inspection_category', u'department_bureau', u'address', u'property_group', u'ssa', u'latitude', u'longitude', u'location', u'log_lat', u'new_lat'], dtype='object')

# %%
df.violation_code.nunique
# Out:
# <bound method Series.nunique of 0     CN065014
# 1     CN044013
# 2     CN104035
# 3     CN196029
# 4     CN104015
# 5     CN190019
# 6     CN015062
# 7     CN065034
# 8     CN196029
# 9     CN190019
# 10    CN104065
# 11    CN063014
# 12    CN070024
# 13    CN193019
# 14    CN041063
# ...
# 49985    CN105035
# 49986    RF302041
# 49987      NC2021
# 49988    CN198019
# 49989    CN073014
# 49990    CN190019
# 49991    CN104055
# 49992    CN131026
# 49993    CN074014
# 49994    CN194039
# 49995    CN063014
# 49996    CN070024
# 49997    CN031013
# 49998    CN135016
# 49999    CN190019
# Name: violation_code, Length: 50000, dtype: object>

# %%
subsetdf.head()
# Out:
#          id violation_last_modified_date violation_date violation_code  \
# 13  5063459                   05/20/2015     2015-05-20       CN193019
# 15  5063885                   05/21/2015     2015-05-20         BR1001
# 18  5063320                   05/20/2015     2015-05-20       CN193019
# 20  5064410                   05/20/2015     2015-05-20       CN193039
# 21  5064489                   05/20/2015     2015-05-20       CN193039
#
#    violation_status violation_status_date           violation_description  \
# 13             OPEN                   NaN  REPAIR/WRECK DANGER RESID PREM
# 15             OPEN                   NaN    OWNER OR LICENSED CONTRACTOR
# 18             OPEN                   NaN  REPAIR/WRECK DANGER RESID PREM
# 20             OPEN                   NaN   POST OWNER NAME OF VACNT BLDG
# 21             OPEN                   NaN   POST OWNER NAME OF VACNT BLDG
#
#    violation_location violation_inspector_comments  \
# ...

# %%
df[3:10]
# Out:
#         id violation_last_modified_date violation_date violation_code  \
# 3  5064019                   05/21/2015     2015-05-21       CN196029
# 4  5064139                   05/21/2015     2015-05-21       CN104015
# 5  5064153                   05/21/2015     2015-05-21       CN190019
# 6  5064141                   05/21/2015     2015-05-21       CN015062
# 7  5064257                   05/21/2015     2015-05-21       CN065034
# 8  5064728                   05/21/2015     2015-05-21       CN196029
# 9  5064742                   05/21/2015     2015-05-21       CN190019
#
#   violation_status violation_status_date          violation_description  \
# 3             OPEN                   NaN     POST OWNER/MANAGERS NAME/#
# 4             OPEN                   NaN  REPLCE WINDOW PANES, PLEXGLAS
# 5             OPEN                   NaN     ARRANGE PREMISE INSPECTION
# 6             OPEN                   NaN       OBSTRUCTIONS IN EXIT WAY
# ...

# %%
pd.crosstab(df.violation_code, df.inspection_status)
# Out:
# inspection_status  CLOSED  FAILED  HOLD  PASSED
# violation_code
# 020008                  0       0     0       1
# 190019                  1      16     0       8
# 199029                 77     318     0     166
# BR1000                  3       0     0      10
# BR1001                 84       0     0     155
# BR1010                  5       0     0       5
# BR1023                  1       0     0       0
# BR1024                  0       0     0       1
# BR1041                  3       0     0       3
# BR1042                  2       0     0       1
# BR1043                  0       0     0       1
# BR1050                  5       0     0       1
# BR1052                  2       0     0       2
# BR1054                  1       0     0       0
# BR1060                  0       0     0       1
# BR1061                  1       0     0       1
# BR1062                  1       0     0       3
# BR1063                  7       0     0      16
# ...

# %%
pd.unique(df.id)
# Out:
# array([5063843, 5063990, 5064022, ..., 1430847, 1734149, 1834762])

# %%
pd.crosstab(df.department_bureau, df.inspection_status)
# Out:
# inspection_status           CLOSED  FAILED  HOLD  PASSED
# department_bureau
# BOILER                         286       0     0     454
# CONSERVATION                  1252   28208     3    3193
# CONSTRUCTION EQUIPMENT           5       1     0       0
# DEMOLITION                    3181       4     0       0
# ELECTRICAL                      12    1110     0     429
# ELEVATOR                       122     951     0     551
# IRON                            23     297     0     173
# NEW CONSTRUCTION                64    1257     0      54
# PLUMBING                        10    1325     0      77
# REFRIGERATION                   19     622     0     291
# SIGNS                            6     310     0      23
# SPECIAL INSPECTION PROGRAM      74     250     0     129
# SPECIAL TASK FORCE             124    3640     0     727
# VENTILATION                     16     379     1     317
# WATER                            5      17     0       8

# %%
df.groupby('inspection_status').count()
# Out:
#                       id  violation_last_modified_date  violation_date  \
# inspection_status
# CLOSED              5199                          5199            5199
# FAILED             38371                         38371           38371
# HOLD                   4                             4               4
# PASSED              6426                          6426            6426
#
#                    violation_code  violation_status  violation_status_date  \
# inspection_status
# CLOSED                       5199              5199                    796
# FAILED                      38371             38371                   6463
# HOLD                            4                 4                      0
# PASSED                       6426              6426                   6253
#
#                    violation_description  violation_location  \
# inspection_status
# CLOSED                              5191                 619
# ...

# %%
pd.unique(df.department_bureau)
# Out:
# array(['CONSERVATION', 'DEMOLITION', 'BOILER', 'PLUMBING', 'VENTILATION',
#        'ELECTRICAL', 'ELEVATOR', 'SPECIAL TASK FORCE', 'WATER',
#        'SPECIAL INSPECTION PROGRAM', 'REFRIGERATION', 'SIGNS', 'IRON',
#        'NEW CONSTRUCTION', 'CONSTRUCTION EQUIPMENT'], dtype=object)

# %%
len(pd.unique(df.violation_code))
# Out:
# 757

# %%
pd.unique(df.violation_description)
# Out:
# array(['REPAIR LINTELS', 'PIPE OPENING W/NONCOMBUST MATL',
#        'MAINTAIN WINDOW', 'POST OWNER/MANAGERS NAME/#',
#        'REPLCE WINDOW PANES, PLEXGLAS', 'ARRANGE PREMISE INSPECTION',
#        'OBSTRUCTIONS IN EXIT WAY', 'REPAIR WINDOW SILLS',
#        'REPAIR WINDOW HARDWARE', 'CHIMNEY', 'REPAIR PORCH SYSTEM',
#        'REPAIR/WRECK DANGER RESID PREM', 'CUT OR REMOVE HIGH WEEDS',
#        'OWNER OR LICENSED CONTRACTOR', 'OPEN',
#        'SERVICE WALK, PASSAGE, AREAWAY', 'REPAIR EXTERIOR STAIR',
#        'POST OWNER NAME OF VACNT BLDG', 'INTERNAL', 'EGRESS -BASEMENT',
#        'EGRESS', 'REPAIR EXTERIOR WALL', 'PROVIDE DEADLOCK FOR ENTRANCE',
#        'PROVIDE GUTTER & DOWNSPOUT', 'WATCHMAN', 'REPAIR COPING',
#        'FILE BLDG REGISTRATION', 'UNAPPROVED HEATING DEVICE',
#        'ARRANGE COMPLETED PERMIT INSP.', 'MAINTAN BLDG IN SAFE CONDITION',
#        'DWELLING CLEAN AND SANITARY', 'PROVIDE GUARD RAIL 42 IN HIGH',
# ...

# %%
pd.crosstab(df.violation_description, df.inspection_status)
# Out:
# inspection_status               CLOSED  FAILED  HOLD  PASSED
# violation_description
# 1-HR HEATING PLANT ENCLOSURE         1      27     0       4
# 1-HR HEATING PLANT SEPARATION        0       6     0       2
# 1-HR STAIR ENCLOSURE, <3 STORY       3      33     0       5
# 1-HR STAIR ENCLOSURE, HOTEL          0       5     0       0
# 1/2HR FLR OVER BSMT,3+DU,PRE57       1       5     0       0
# 14 GAUGE HOOD/STACK ABOVE ROOF       0       3     0       1
# 1HR ENCL FLR TO FLR SHAFT/DUCT       0       4     0       0
# 1HR FLR OVER BSMT, 1 OR 2 DU         2      27     0       4
# 1HR PUB.CORIDR NON-RES/SPRNKLD       0       2     0       0
# 1HR PUB.CORRIDOR ASSEMBLY UNIT       0       2     0       0
# 1HR PUB.CORRIDOR IN MULT. D.U.       0      18     0       2
# 1HR SEP-D.U.  AND REST OF BLDG       2      21     0       8
# 2-HR HEATING PLANT ENCLOSURE         0       3     0       0
# 2-HR STAIR ENCLOSURE, 4+ STORY       0      24     0       0
# ...

# %%
# %matplotlib inline

# %%
pd.crosstab(df.violation_date, df.inspection_status).plot()

# %%
df.columns
# Out:
# Index([u'id', u'violation_last_modified_date', u'violation_date', u'violation_code', u'violation_status', u'violation_status_date', u'violation_description', u'violation_location', u'violation_inspector_comments', u'violation_ordinance', u'inspector_id', u'inspection_number', u'inspection_status', u'inspection_waived', u'inspection_category', u'department_bureau', u'address', u'property_group', u'ssa', u'latitude', u'longitude', u'location', u'log_lat', u'new_lat'], dtype='object')

# %%
#Groupby - counts inspection category by date
grouped = df[['id','violation_date', 'inspection_category']].groupby(['violation_date', 'inspection_category']).count()

# %%
grouped
# Out:
#                                     id
# violation_date inspection_category
# 2006-01-01     PERIODIC             10
# 2006-01-02     COMPLAINT             1
#                PERIODIC             50
# 2006-01-03     COMPLAINT            15
#                PERIODIC              1
# 2006-01-04     COMPLAINT            32
#                PERIODIC              4
# 2006-01-05     COMPLAINT            18
#                PERIODIC              2
# 2006-01-06     COMPLAINT            19
#                PERIODIC              5
# 2006-01-07     COMPLAINT             1
# 2006-01-09     COMPLAINT            11
#                PERIODIC              7
# 2006-01-10     COMPLAINT            13
#                PERIODIC              3
# 2006-01-11     COMPLAINT            24
#                PERIODIC              2
#                PERMIT                1
# 2006-01-12     COMPLAINT            24
#                PERIODIC              2
#                PERMIT                1
# ...

# %%
grouped.plot(figsize=(15,5))

# %%
#To see alll the categories in either a table or plot use unstack
unstacked = grouped.unstack(level= -1)
# Out:
#                            id
# inspection_category COMPLAINT PERIODIC PERMIT REGISTRATION
# violation_date
# 2006-01-01                NaN       10    NaN          NaN
# 2006-01-02                  1       50    NaN          NaN
# 2006-01-03                 15        1    NaN          NaN
# 2006-01-04                 32        4    NaN          NaN
# 2006-01-05                 18        2    NaN          NaN
# 2006-01-06                 19        5    NaN          NaN
# 2006-01-07                  1      NaN    NaN          NaN
# 2006-01-09                 11        7    NaN          NaN
# 2006-01-10                 13        3    NaN          NaN
# 2006-01-11                 24        2      1          NaN
# 2006-01-12                 24        2      1          NaN
# 2006-01-13                 18      NaN      1          NaN
# 2006-01-14                  2      NaN    NaN          NaN
# 2006-01-17                 18        1    NaN          NaN
# ...

# %%
unstacked.plot(figsize = (12,5))

# %%
#stack/unstack changes the relational. 
#Pivot_table allows you to take a combination of columns and rows and do aggregations on them and shifts. 
#Melt is like melt in R.
#We want to get a plot like this but just looking at the last year. 

unstacked['2015'] #we have a datetime index so we can subset by year
# Out:
#                            id
# inspection_category COMPLAINT PERIODIC PERMIT REGISTRATION
# violation_date
# 2015-01-02                  4        1    NaN          NaN
# 2015-01-05                 10        1      1          NaN
# 2015-01-06                 18        1    NaN          NaN
# 2015-01-07                 16      NaN    NaN          NaN
# 2015-01-08                  9        1      1          NaN
# 2015-01-09                 16      NaN    NaN          NaN
# 2015-01-12                  4        3    NaN          NaN
# 2015-01-13                 11        4      1          NaN
# 2015-01-14                 13        1    NaN          NaN
# 2015-01-15                 14      NaN      3          NaN
# 2015-01-16                  9      NaN      2          NaN
# 2015-01-20                 11        1    NaN          NaN
# 2015-01-21                 13        3      1          NaN
# 2015-01-22                 16        3    NaN          NaN
# ...

# %%
#To have a range
unstacked['2014-01':'2014-03'].plot(figsize=(12,5))

# %%
#These are all the violations, let's see only open ones. So let's subtype the dataframe
df1 = df[df['violation_status'] == "OPEN"] #this creates a series of true/false true false, and we pass through the df.

# %%
#reset_index is to have an index back to a column, it just creates a generic index (0,1,2,...) and sets everything else as acolumn
#Now I want to count for everyday for every single violation type. I will use a pivot table.
#Pivot tables are good for aggregations. You need to choose ID variable first (in this case violation_date) and then the variabl you want to pivot on, the variable you wnt to sum. 
#This reurns a dataframe that for each date you get a sum of each type of violation.

#We have a datetime index so we can do aggregations very easily. e.g. for month
#avg_monthly = grouped.resample('M', how='mean')
#for counts you would put how='sum'
#Take a look at this notebook 9a and also the feature engineering one, on how to create dummies and so on.
#Crosstab is very good for categorical data.
